# %%
from bs4 import BeautifulSoup
import requests

# %%
def extract(pageNum):
  url= f'https://devjobs.at/jobs/search?text=wien&pagе={pageNum})'
  headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36"
  }
  r = requests.get(url, headers)
  return r.status_code

# %%
BeautifulSoup(page.text, 'html')

# %%
Website
  ↓
BeautifulSoup (scraping)
  ↓
Pandas DataFrame
  ↓
SQLite database   ← (this is what you add)
  ↓
Analysis & plots (Person B)

We scraped job data using BeautifulSoup, structured it using pandas, and stored it in a SQLite database for further analysis and visualization.
